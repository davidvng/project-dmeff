# %%
import numpy as np
import matplotlib.pyplot as plt

masses = np.array([1e-6, 1e-3, 1., 1e3])

n6 = np.array([1.02e-23, 4.34e-16, 5.73e-13, 6.88e-10])
n4 = np.array([8.48e-25, 7.32e-19, 1.34e-16, 1.15e-13])
n2 = np.array([3.54e-26, 3.36e-23, 2.02e-20, 4.15e-17])
n0 = np.array([9.90e-28, 5.78e-27, 5.53e-24, 8.71e-21])
nn2 = np.array([1.12e-32, 6.38e-32, 2.10e-29, 4.09e-26])
nn4 = np.array([1.73e-38, 5.09e-38, 3.43e-35, 5.43e-32])

f,ax = plt.subplots()

ax.plot(masses, nn4, marker='.', label='n = -4')
ax.plot(masses, nn2, marker='.', label='n = -2')
ax.plot(masses, n0, marker='.', label='n = 0')
ax.plot(masses, n2, marker='.', label='n = 2')
ax.plot(masses, n4, marker='.', label='n = 4')
ax.plot(masses, n6, marker='.', label='n = 6', color='y')
ax.fill_between(masses, nn4, 1.0e-8, alpha=0.2)
ax.fill_between(masses, nn2, 1.0e-8, alpha=0.2)
ax.fill_between(masses, n0, 1.0e-8, alpha=0.2)
ax.fill_between(masses, n2, 1.0e-8, alpha=0.2)
ax.fill_between(masses, n4, 1.0e-8, alpha=0.2)
ax.fill_between(masses, n6, 1.0e-8, alpha=0.2, color='y')
ax.set_xlabel('Dark Matter Particle Mass (in electron masses), $m_\chi$ $[\mathrm{GeV}]$')
ax.set_ylabel('Interaction Cross Section, $\sigma_e$ $[\mathrm{cm}^2]$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim([1.0e-6, 1.0e3])
ax.set_ylim([1.0e-40, 1.0e-8])
plt.legend(loc="upper left", framealpha=0.5)
plt.savefig('dme_alln.pdf')
plt.savefig('dme_alln.png', dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

masses = np.array([1e-6, 1e-3, 1., 1e3])

electron = np.array([9.90e-28, 5.78e-27, 5.53e-24, 8.71e-21])
proton = np.array([5.02e-27, 2.45e-26, 1.96e-25, 5.64e-23])

f,ax = plt.subplots()

ax.plot(masses, electron, marker='.', label='DM-electron (n = 0)')
ax.plot(masses, proton, marker='.', label='DM-proton (n = 0)')
ax.fill_between(masses, electron, 1.0e-20, alpha=0.2)
ax.fill_between(masses, proton, 1.0e-20, alpha=0.2)
ax.set_xlabel('Dark Matter Particle Mass (in electron masses), $m_\chi$ $[\mathrm{GeV}]$')
ax.set_ylabel('Interaction Cross Section, $\sigma_e$ $[\mathrm{cm}^2]$')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim([1.0e-6, 1.0e3])
ax.set_ylim([1.0e-30, 1.0e-20])
plt.legend(loc="lower right", framealpha=0.5)
plt.savefig('dme_dmb_n0.pdf')
plt.savefig('dme_dmb_n0.png', dpi=300)

# %%
print(abs(5.02e-27-9.90e-28)/5.02e-27)
print(5.02e-27/9.90e-28)
# Out:
# 0.802788844621514
# 5.070707070707071

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

cdms = np.array([5.00000e-04,1.38085e-25,5.50000e-04,3.13315e-27,6.00000e-04,8.99145e-28,6.50000e-04,3.93901e-28,7.00000e-04,2.01676e-28,7.50000e-04,1.17071e-28,8.00000e-04,7.22042e-29,9.00000e-04,3.14826e-29,1.00000e-03,1.56417e-29,2.00000e-03,3.92673e-32,3.00000e-03,4.47586e-33,4.00000e-03,1.98949e-33,5.00000e-03,1.37514e-33,6.00000e-03,1.15730e-33,7.00000e-03,1.06302e-33,8.00000e-03,9.90200e-34,9.00000e-03,9.13049e-34,1.00000e-02,8.69703e-34,2.00000e-02,9.11066e-34,5.00000e-02,1.63076e-33,1.00000e-01,2.94152e-33,2.00000e-01,5.59493e-33,5.00000e-01,1.35793e-32,1.00000e+00,2.68942e-32,1.00000e+01,2.66588e-31])

mass_cdms  = cdms[0::2] * 1000.
sigma_cdms = cdms[1::2]

### Xenon1T 2019, 1907.11485
# must multiply mass by 1000 to convert from GeV to MeV
xenon = np.array([0.01,1.95861527453373E-29,0.02,1.16324024925374E-36,0.03,3.27911471179496E-38,0.05,1.13917098671609E-39,0.07,3.87604679543973E-40,0.1,1.8528233658565E-40,0.14,1.28238576955141E-40,0.2,1.15881740196796E-40,0.3,1.20371112878008E-40,0.5,1.51960795846531E-40,0.7,1.89734211829597E-40,1.0,2.49201313397697E-40,2.0,4.52765785509263E-40,5.0,1.06965796244793E-39,10.0,2.09971099833644E-39])

mass_xenon  = xenon[0::2] * 1000.
sigma_xenon = xenon[1::2]

sigma_chains = np.array([9.90e-28, 5.78e-27, 5.53e-24, 8.71e-21])
mass_chains = np.array([1e-3, 1., 1e3, 1e6]) # masses in MeV


f,ax = plt.subplots()

ax.plot(mass_chains,sigma_chains,label='Planck (this work)',color='black',linewidth=2.0)
ax.plot(mass_damic,sigma_damic,label='DAMIC')
ax.plot(mass_ds,sigma_ds,label='DarkSide-50')
ax.plot(mass_edel,sigma_edel,label='EDELWEISS')
ax.plot(mass_sensei,sigma_sensei,label='SENSEI')
ax.plot(mass_cdms,sigma_cdms,label='SuperCDMS')
ax.plot(mass_xenon,sigma_xenon,label='Xenon1T')
ax.fill_between(mass_chains, sigma_chains, 1.0e-20, alpha=0.1,color='black')
ax.fill_between(mass_damic, sigma_damic, 1.0e-20, alpha=0.1)
ax.fill_between(mass_ds,sigma_ds, 1.0e-20, alpha=0.1)
ax.fill_between(mass_edel,sigma_edel, 1.0e-20, alpha=0.1)
ax.fill_between(mass_sensei,sigma_sensei, 1.0e-20, alpha=0.1)
ax.fill_between(mass_cdms,sigma_cdms, 1.0e-20, alpha=0.1)
ax.fill_between(mass_xenon,sigma_xenon, 1.0e-20, alpha=0.1)

ax.set_xlabel('Dark Matter Particle Mass (in electron masses), $m_\chi$ $[\mathrm{MeV}]$')
ax.set_ylabel('Interaction Cross Section, $\sigma_e$ $[\mathrm{cm}^2]$')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim([1.0e-3, 1.0e4])
ax.set_ylim([1.0e-42, 1.0e-20])

ax.legend()

plt.savefig('dme_directdetect.pdf')
plt.savefig('dme_directdetect.png', dpi=300)
